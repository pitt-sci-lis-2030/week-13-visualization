# %% [markdown]
# # Week 13 Activities

# %%
import pandas as pd

# %% [markdown]
# ## Q: In Allegheny county, do bigger homes mean more dogs?
#
#
# ![Dog Analytics](https://media.giphy.com/media/mCRJDo24UvJMA/giphy.gif)
#
# First step is identifying the the datasets.
#
#
# * [AC property assessment ](https://data.wprdc.org/dataset/property-assessments)
# * [AC dog license ](https://data.wprdc.org/dataset/allegheny-county-dog-licenses)
#
#
# For each dataset, it is important to think about:
# * What entities are represented in the data? What does each row represent?
# * Is there any information shared across the two datasets?
# * What information in the datasets can we use to answer our question?
#     * What operation might we need to perform to get the information we need?

# %% [markdown]
# Look at the *Data Dictionary* for each dataset for information about the columns
#
# [Property Data Dictionary](https://data.wprdc.org/dataset/property-assessments/resource/d31e1b1c-215d-4693-9898-154ca49050a4)
#
# [Dog Data Dictionary](https://data.wprdc.org/dataset/allegheny-county-dog-licenses/resource/24771463-fec6-4d35-9662-2258575cd47d)

# %% [markdown]
# What entities are represented in the data? What does each row represent?
#
# * **Property assessment** - Each row is a house in Allegheny county with
# * **Dogs** - Each row is a dog license
#
# Is there any information shared across the two datasets?
#
# * **Property assessment** - Zip code in the `OwnerZip` column
# * **Dogs** - Zip code in the`PROPERTYZIP` column
#
# What information in the datasets do we need to answer our question? Is there a column with that information
#
# * **Property assessment** - Yes, the column `FINISHEDLIVINGAREA` contains the "Finished living area, as measured from the outside of the structure."
# * **Dogs** - Each row is a dog license, but there isn't a specific column rather it is the datasets
#
# What operation might we need to perform to get the information we need?
#
# * **Property assessment** - Each row is a house with size, so compute the mean by zip to get average house size per zip code
# * **Dogs** - Each row is a dog license, so count the rows by Zip code to get dogs per zip code

# %% [markdown]
# ## How do we Load the data into Python (with Pandas)
#
# Both datasets have been downloaded from the WPRDC and placed in the `files` directory as `dogs.csv` and `properties.csv`

# %%
# load the properties file into a dataframe and make sure the zip codes are strings
properties = pd.read_csv("files/properties.csv.zip", compression="zip", dtype={'PROPERTYZIP': 'str'})
properties
# Out:
# /Users/mcburton/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (19,20,29,30,38,46,57,83) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#                    PARID  PROPERTYHOUSENUM PROPERTYFRACTION PROPERTYADDRESS  \
# 0       0001G00201000000             125.0                          1ST AVE
# 1       0001G00203000000               0.0                          1ST AVE
# 2       0001G00204000000             135.0                          1ST AVE
# 3       0001D00153000000             501.0                        MARKET ST
# 4       0001D00156000000             501.0                        MARKET ST
# ...                  ...               ...              ...             ...
# 581121  1658G00035000000             916.0                         PARK PLZ
# 581122  1658H00022000000             933.0                         PARK PLZ
# 581123  1500D00008000000            3035.0                       WEXFORD RD
# 581124  1499F00028000000             190.0                      LIMERICK RD
# 581125  1658D00019000000             602.0                   GEORGETOWNE CT
#
#        PROPERTYCITY PROPERTYSTATE PROPERTYUNIT PROPERTYZIP  MUNICODE  \
# 0        PITTSBURGH            PA                    15222       101
# 1        PITTSBURGH            PA                    15222       101
# 2        PITTSBURGH            PA                    15222       101
# 3        PITTSBURGH            PA                    15222       101
# 4        PITTSBURGH            PA                    15222       101
# ...             ...           ...          ...         ...       ...
# 581121      WEXFORD            PA                    15090       935
# 581122      WEXFORD            PA                    15090       935
# 581123      WEXFORD            PA                    15090       935
# 581124      WEXFORD            PA                    15090       935
# 581125      WEXFORD            PA                    15090       935
#
#                       MUNIDESC  ...    ASOFDATE MUNICIPALITY NEIGHBORHOOD  \
# 0       1st Ward  - PITTSBURGH  ...  2021-04-01          NaN          NaN
# 1       1st Ward  - PITTSBURGH  ...  2021-04-01          NaN          NaN
# 2       1st Ward  - PITTSBURGH  ...  2021-04-01          NaN          NaN
# 3       1st Ward  - PITTSBURGH  ...  2021-04-01          NaN          NaN
# 4       1st Ward  - PITTSBURGH  ...  2021-04-01          NaN          NaN
# ...                        ...  ...         ...          ...          ...
# 581121                  Pine    ...  2021-04-01          NaN          NaN
# 581122                  Pine    ...  2021-04-01          NaN          NaN
# 581123                  Pine    ...  2021-04-01          NaN          NaN
# 581124                  Pine    ...  2021-04-01          NaN          NaN
# 581125                  Pine    ...  2021-04-01          NaN          NaN
#
#        PGH_COUNCIL_DISTRICT PGH_WARD PGH_PUBLIC_WORKS_DIVISION  \
# 0                       NaN      NaN                       NaN
# 1                       NaN      NaN                       NaN
# 2                       NaN      NaN                       NaN
# 3                       NaN      NaN                       NaN
# 4                       NaN      NaN                       NaN
# ...                     ...      ...                       ...
# 581121                  NaN      NaN                       NaN
# 581122                  NaN      NaN                       NaN
# 581123                  NaN      NaN                       NaN
# 581124                  NaN      NaN                       NaN
# 581125                  NaN      NaN                       NaN
#
#        PGH_POLICE_ZONE PGH_FIRE_ZONE TRACT BLOCK_GROUP
# 0                  NaN           NaN   NaN         NaN
# 1                  NaN           NaN   NaN         NaN
# 2                  NaN           NaN   NaN         NaN
# 3                  NaN           NaN   NaN         NaN
# 4                  NaN           NaN   NaN         NaN
# ...                ...           ...   ...         ...
# 581121             NaN           NaN   NaN         NaN
# 581122             NaN           NaN   NaN         NaN
# 581123             NaN           NaN   NaN         NaN
# 581124             NaN           NaN   NaN         NaN
# 581125             NaN           NaN   NaN         NaN
#
# [581126 rows x 95 columns]

# %%
# look at the column names and types
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581126 entries, 0 to 581125
# Data columns (total 95 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   PARID                      581126 non-null  object
#  1   PROPERTYHOUSENUM           581120 non-null  float64
#  2   PROPERTYFRACTION           581126 non-null  object
#  3   PROPERTYADDRESS            581126 non-null  object
#  4   PROPERTYCITY               581124 non-null  object
#  5   PROPERTYSTATE              581126 non-null  object
#  6   PROPERTYUNIT               581126 non-null  object
#  7   PROPERTYZIP                581125 non-null  object
#  8   MUNICODE                   581126 non-null  int64
#  9   MUNIDESC                   581126 non-null  object
#  10  SCHOOLCODE                 581126 non-null  int64
#  11  SCHOOLDESC                 581126 non-null  object
#  12  LEGAL1                     581105 non-null  object
#  13  LEGAL2                     517245 non-null  object
#  14  LEGAL3                     337845 non-null  object
#  15  NEIGHCODE                  581126 non-null  object
#  16  NEIGHDESC                  580209 non-null  object
#  17  TAXCODE                    581126 non-null  object
#  18  TAXDESC                    581126 non-null  object
#  19  TAXSUBCODE                 1718 non-null    object
#  20  TAXSUBCODE_DESC            1718 non-null    object
#  21  OWNERCODE                  581126 non-null  int64
#  22  OWNERDESC                  581126 non-null  object
#  23  CLASS                      0 non-null       float64
#  24  CLASSDESC                  581126 non-null  object
#  25  USECODE                    581126 non-null  int64
#  26  USEDESC                    581124 non-null  object
#  27  LOTAREA                    581126 non-null  int64
#  28  HOMESTEADFLAG              301716 non-null  object
#  29  CLEANGREEN                 1707 non-null    object
#  30  FARMSTEADFLAG              6 non-null       object
#  31  ABATEMENTFLAG              596 non-null     object
#  32  RECORDDATE                 349891 non-null  object
#  33  SALEDATE                   574122 non-null  object
#  34  SALEPRICE                  571480 non-null  float64
#  35  SALECODE                   573161 non-null  object
#  36  SALEDESC                   571674 non-null  object
#  37  DEEDBOOK                   530910 non-null  object
#  38  DEEDPAGE                   530695 non-null  object
#  39  PREVSALEDATE               381008 non-null  object
#  40  PREVSALEPRICE              379295 non-null  float64
#  41  PREVSALEDATE2              205001 non-null  object
#  42  PREVSALEPRICE2             204420 non-null  float64
#  43  CHANGENOTICEADDRESS1       581126 non-null  object
#  44  CHANGENOTICEADDRESS2       581126 non-null  object
#  45  CHANGENOTICEADDRESS3       581126 non-null  object
#  46  CHANGENOTICEADDRESS4       568941 non-null  object
#  47  COUNTYBUILDING             581126 non-null  int64
#  48  COUNTYLAND                 581126 non-null  int64
#  49  COUNTYTOTAL                581126 non-null  int64
#  50  COUNTYEXEMPTBLDG           581126 non-null  int64
#  51  LOCALBUILDING              581126 non-null  int64
#  52  LOCALLAND                  581126 non-null  int64
#  53  LOCALTOTAL                 581126 non-null  int64
#  54  FAIRMARKETBUILDING         581126 non-null  int64
#  55  FAIRMARKETLAND             581126 non-null  int64
#  56  FAIRMARKETTOTAL            581126 non-null  int64
#  57  STYLE                      446068 non-null  object
#  58  STYLEDESC                  446068 non-null  object
#  59  STORIES                    446058 non-null  float64
#  60  YEARBLT                    446074 non-null  float64
#  61  EXTERIORFINISH             446061 non-null  float64
#  62  EXTFINISH_DESC             446061 non-null  object
#  63  ROOF                       445338 non-null  float64
#  64  ROOFDESC                   445338 non-null  object
#  65  BASEMENT                   445968 non-null  float64
#  66  BASEMENTDESC               445968 non-null  object
#  67  GRADE                      446063 non-null  object
#  68  GRADEDESC                  446063 non-null  object
#  69  CONDITION                  445997 non-null  float64
#  70  CONDITIONDESC              445997 non-null  object
#  71  CDU                        445997 non-null  object
#  72  CDUDESC                    445997 non-null  object
#  73  TOTALROOMS                 445994 non-null  float64
#  74  BEDROOMS                   446027 non-null  float64
#  75  FULLBATHS                  445944 non-null  float64
#  76  HALFBATHS                  442178 non-null  float64
#  77  HEATINGCOOLING             445889 non-null  object
#  78  HEATINGCOOLINGDESC         445889 non-null  object
#  79  FIREPLACES                 411156 non-null  float64
#  80  BSMTGARAGE                 425652 non-null  float64
#  81  FINISHEDLIVINGAREA         446074 non-null  float64
#  82  CARDNUMBER                 446074 non-null  float64
#  83  ALT_ID                     26201 non-null   object
#  84  TAXYEAR                    581126 non-null  int64
#  85  ASOFDATE                   581126 non-null  object
#  86  MUNICIPALITY               0 non-null       float64
#  87  NEIGHBORHOOD               0 non-null       float64
#  88  PGH_COUNCIL_DISTRICT       0 non-null       float64
#  89  PGH_WARD                   0 non-null       float64
#  90  PGH_PUBLIC_WORKS_DIVISION  0 non-null       float64
#  91  PGH_POLICE_ZONE            0 non-null       float64
#  92  PGH_FIRE_ZONE              0 non-null       float64
#  93  TRACT                      0 non-null       float64
#  94  BLOCK_GROUP                0 non-null       float64
# dtypes: float64(28), int64(16), object(51)
# memory usage: 421.2+ MB

# %%
# load the dog file into a dataframe and make sure the zip codes are strings
dogs = pd.read_csv("files/dogs.csv", dtype={'OwnerZip': 'str'})
dogs
# Out:
#                       LicenseType               Breed        Color  \
# 0      Dog Lifetime Spayed Female  LABRADOR RETRIEVER       YELLOW
# 1      Dog Lifetime Neutered Male  LABRADOR RETRIEVER        BROWN
# 2      Dog Lifetime Spayed Female               MIXED      SPOTTED
# 3      Dog Lifetime Spayed Female             LAB MIX        BROWN
# 4      Dog Lifetime Spayed Female        AUS SHEPHERD        MULTI
# ...                           ...                 ...          ...
# 34516  Dog Lifetime Spayed Female  LABRADOR RETRIEVER       YELLOW
# 34517  Dog Lifetime Neutered Male      POMERANIAN MIX        BLACK
# 34518           Dog Lifetime Male        GOLDENDOODLE        BROWN
# 34519  Dog Lifetime Spayed Female               MIXED  WHITE/BLACK
# 34520  Dog Lifetime Spayed Female             LAB MIX        BLACK
#
#           DogName OwnerZip  ExpYear            ValidDate
# 0           SASHA    15137     2099  2005-01-31T00:00:00
# 1            JAKE    15129     2099  2004-06-21T00:00:00
# 2          SHILOH    15129     2099  2006-01-20T00:00:00
# 3         BLONDIE    15140     2099  2005-07-18T00:00:00
# 4           SASHA    15238     2099  2004-02-25T00:00:00
# ...           ...      ...      ...                  ...
# 34516        LELA    15108     2099  2017-05-31T15:33:00
# 34517   SPARTACUS    15108     2099  2017-05-31T15:08:42
# 34518      PARKER    15025     2099  2017-05-31T15:33:00
# 34519       LILLY    15241     2099  2017-05-31T15:33:01
# 34520  BELLA FODI    15209     2099  2017-05-31T15:33:01
#
# [34521 rows x 7 columns]

# %%
# look at the column names and types
dogs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34521 entries, 0 to 34520
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   LicenseType  34521 non-null  object
#  1   Breed        34520 non-null  object
#  2   Color        34501 non-null  object
#  3   DogName      34521 non-null  object
#  4   OwnerZip     34521 non-null  object
#  5   ExpYear      34521 non-null  int64
#  6   ValidDate    34521 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 1.8+ MB

# %% [markdown]
# ## What operation might we need to perform to get the information we need?
#
# * **Property assessment** - Each row is a house with size, so compute the mean by zip to get average house size per zip code
# * **Dogs** - Each row is a dog license, so count the rows by Zip code to get dogs per zip code

# %%
# Create a subset of the property data and drop the null values
properties_size_clean = properties[["PROPERTYZIP", "FINISHEDLIVINGAREA"]].dropna()
properties_size_clean
# Out:
#        PROPERTYZIP  FINISHEDLIVINGAREA
# 25           15222              1529.0
# 26           15222              1310.0
# 27           15222               877.0
# 28           15222              3140.0
# 29           15222              1399.0
# ...            ...                 ...
# 581121       15090              2414.0
# 581122       15090              2436.0
# 581123       15090              1230.0
# 581124       15090              2664.0
# 581125       15090              3050.0
#
# [446074 rows x 2 columns]

# %%
# compute the average living area per zip code
avg_livingarea_per_zip = properties_size_clean.groupby("PROPERTYZIP").mean()
# rename the column to be less bad
avg_livingarea_per_zip = avg_livingarea_per_zip.rename(columns={"FINISHEDLIVINGAREA":"size"}, index={"PROPERTYZIP":"zip"})
# rename the index to be less bad
avg_livingarea_per_zip = avg_livingarea_per_zip.rename_axis(index={"PROPERTYZIP":"zip"})
# display the 
avg_livingarea_per_zip
# Out:
#               size
# zip
# 15003  1418.588757
# 15005  2944.722222
# 15006  1284.822222
# 15007  1793.193548
# 15012  1657.000000
# ...            ...
# 15668  2109.483871
# 16046  3079.413907
# 16056  1716.333333
# 16059  1757.585586
# 16229  1512.600000
#
# [116 rows x 1 columns]

# %%
# create a subset of the dog data with just zip and name
just_dog_names = dogs[["OwnerZip", "DogName"]]
just_dog_names
# Out:
#       OwnerZip     DogName
# 0        15137       SASHA
# 1        15129        JAKE
# 2        15129      SHILOH
# 3        15140     BLONDIE
# 4        15238       SASHA
# ...        ...         ...
# 34516    15108        LELA
# 34517    15108   SPARTACUS
# 34518    15025      PARKER
# 34519    15241       LILLY
# 34520    15209  BELLA FODI
#
# [34521 rows x 2 columns]

# %%
# Group by Zip code and then count the rows to get number of dogs per zip
dogs_per_zip = just_dog_names.groupby("OwnerZip").count()

dogs_per_zip = dogs_per_zip.rename(columns={"DogName":"dogs"})
dogs_per_zip = dogs_per_zip.rename_axis(index={"OwnerZip":"zip"})


dogs_per_zip
# Out:
#        dogs
# zip
# 15003    29
# 15005    47
# 15006     5
# 15007     9
# 15012     2
# ...     ...
# 16342     1
# 32081     1
# 33426     1
# 46845     1
# 47909     1
#
# [136 rows x 1 columns]

# %% [markdown]
# ## Can we visualize the dogs per zip?

# %%
# import geopandas
import geopandas as gpd

# %%
# read in a map of the zip code boundaries so we can viz zip codes
ac_map = gpd.read_file('files/ac-zip-code-boundaries.geojson')
ac_map.plot(); #adding semicolin to clean up output

# %%
# display the geodataframe
ac_map.head()
# Out:
#    OBJECTID    ZIP            NAME     ZIPTYPE STATE STATEFIPS COUNTYFIPS  \
# 0         4  15007      BAKERSTOWN  NON-UNIQUE    PA        42      42003
# 1         5  15014    BRACKENRIDGE  NON-UNIQUE    PA        42      42003
# 2         6  15015  BRADFORD WOODS  NON-UNIQUE    PA        42      42003
# 3         8  15018     BUENA VISTA  NON-UNIQUE    PA        42      42003
# 4        10  15020          BUNOLA      PO BOX    PA        42      42003
#
#   COUNTYNAME S3DZIP        LAT  ...  MFDU    SFDU  BOXCNT  BIZCNT  RELVER  \
# 0  ALLEGHENY    150  40.656688  ...   0.0   107.0    66.0    55.0   1.9.3
# 1  ALLEGHENY    150  40.607964  ...  59.0  1396.0    38.0    76.0   1.9.3
# 2  ALLEGHENY    150  40.636452  ...   0.0   430.0    95.0    56.0   1.9.3
# 3  ALLEGHENY    150  40.289408  ...   0.0   286.0   129.0    22.0   1.9.3
# 4  ALLEGHENY    150  40.219791  ...   0.0     1.0   130.0    13.0   1.9.3
#
#    COLOR                                GlobalID SHAPE.STArea()  \
# 0   10.0  {4768B869-6BC2-4B77-8DC7-A3BB678888D1}   1.337121e+07
# 1    5.0  {D7938129-8427-49A4-8C6C-3A19848432D4}   1.515338e+07
# 2   10.0  {BABB5D5E-1FF4-4E03-BBAB-B84CBB5BFB31}   2.658386e+07
# 3   11.0  {4E2C2FAA-7976-4BEF-8119-BBB65C2F7014}   6.087773e+07
# 4   12.0  {6A1DF0B9-0732-465E-A020-6DBC3DCE93B3}   5.373712e+07
#
#    SHAPE.STLength()                                           geometry
# 0      20129.308124  POLYGON ((-79.92421 40.65181, -79.92422 40.651...
# 1      16855.546429  POLYGON ((-79.73576 40.61129, -79.73574 40.611...
# 2      34637.659348  POLYGON ((-80.07258 40.64492, -80.07241 40.644...
# 3      76466.468736  POLYGON ((-79.80552 40.24101, -79.80592 40.241...
# 4      51181.457073  POLYGON ((-79.92674 40.24185, -79.92674 40.241...
#
# [5 rows x 23 columns]

# %%
# Create a geodataframe with dog counts
dog_map = ac_map.merge(dogs_per_zip, left_on="ZIP", right_on="zip")

# %%
# display our dog counts per zip
dog_map.plot(column="dogs"); #adding semicolin to clean up output

# %% [markdown]
# ### Redd up the chart

# %%
# Create a plot of the dogs column we added to our geodataframe above
ax = dog_map.plot(column="dogs", # use the dog data
                  cmap="Reds",  # use red as our color map
                  legend=True, # add a legend the easy way
                  figsize=(10,10), # make the figure bigger the easy way
                  linewidth=0.5, # add border lines 
                  edgecolor='black') # make the borderlines black

# use the axis object to set the title and turn off axes
ax.set_title("Dogs Per Zip")
ax.axis('off'); #adding semicolin to clean up output

# %% [markdown]
# ## Can we visualize the average house size per zip?

# %%
# create a geodataframe with average house size per zip
property_map = ac_map.merge(avg_livingarea_per_zip, left_on="ZIP", right_on="zip")
property_map.plot(column="size"); #adding semicolin to clean up output

# %% [markdown]
# ### Redd up this chart

# %%
# Create a plot of the dogs column we added to our geodataframe above
ax = property_map.plot(column="size", 
                       cmap="Reds", 
                       legend=True, 
                       figsize=(10,10),
                       linewidth=0.5, 
                       edgecolor='grey')

# use the axis object to set the title and turn off axes
ax.set_title("Average house size per zip")
ax.axis('off');  #adding semicolin to clean up output

# %% [markdown]
# ## Can we create a single dataframe with the dog counts and average house size?

# %%
# look at our home size data
avg_livingarea_per_zip
# Out:
#               size
# zip
# 15003  1418.588757
# 15005  2944.722222
# 15006  1284.822222
# 15007  1793.193548
# 15012  1657.000000
# ...            ...
# 15668  2109.483871
# 16046  3079.413907
# 16056  1716.333333
# 16059  1757.585586
# 16229  1512.600000
#
# [116 rows x 1 columns]

# %%
# look at our dog count data
dogs_per_zip
# Out:
#        dogs
# zip
# 15003    29
# 15005    47
# 15006     5
# 15007     9
# 15012     2
# ...     ...
# 16342     1
# 32081     1
# 33426     1
# 46845     1
# 47909     1
#
# [136 rows x 1 columns]

# %%
# Combine them using the row index rather than column names
zip_dog_house_data = pd.merge(dogs_per_zip, avg_livingarea_per_zip, left_index=True, right_index=True)
zip_dog_house_data
# Out:
#        dogs         size
# zip
# 15003    29  1418.588757
# 15005    47  2944.722222
# 15006     5  1284.822222
# 15007     9  1793.193548
# 15012     2  1657.000000
# ...     ...          ...
# 15642     6  1552.142857
# 15668     4  2109.483871
# 16046    91  3079.413907
# 16059    11  1757.585586
# 16229     4  1512.600000
#
# [115 rows x 2 columns]

# %% [markdown]
# ## Can we visualize the relationship between house size and number of dogs per zip code?

# %%
# make a scatter plot of the 
zip_dog_house_data.plot.scatter(x="size", # set x axis to house size
                                y="dogs"); # set y axis to dog count

# %% [markdown]
# ## Redd up this chart

# %%
# import numpy for calculations
import numpy as np
# import the pyplot interface because we need it to draw the line and save the figure
import matplotlib.pyplot as plt
# use Nate Silver Style
plt.style.use("fivethirtyeight")

# %% [markdown]
# Let's add [best fit line too](https://www.kite.com/python/answers/how-to-plot-a-line-of-best-fit-in-python)! $y = mx + b$

# %%
# set x and y
x = zip_dog_house_data['size']
y = zip_dog_house_data['dogs']

# get the slope and intercept using the np.polyfit function
m, b = np.polyfit(zip_dog_house_data["size"], zip_dog_house_data["dogs"], 1)

# print out 
print(m)
print(b)
# Out:
# 0.050242537168959794
# 215.89582712171443

# %%
# generate a larger chart with a title
zip_dog_house_data.plot.scatter(x="size", # set x axis to house size 
                                y="dogs", # set y axis to dog count
                                figsize=(10,10), # make the chart bigger
                                title="Number of dogs per average house size by zip code"); # give the chart a title

# add the best fit line using the matplotlib pyplot interface
plt.plot(x, m*x + b, linewidth=0.5);

# save to a file
plt.savefig('my-sweet-chart.png')

# %% [markdown]
# ![Dog House](https://media.giphy.com/media/l1L0gd8CAzvYC72gM/giphy.gif)
